# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from sodapy import Socrata
from uszipcode import SearchEngine
import pickle
import json

# %%
# Read csv file
#la_crime_data = pd.read_csv("../Resources/Crime_Data_from_2010_to_Present.csv")

# Get Crime Data from open API
client = Socrata("data.lacity.org", None)

results = client.get("7fvc-faax", limit=2000000)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# Convert to pandas DataFrame
la_crime_data = pd.DataFrame.from_records(results)
la_crime_data.head()
# Out:
#   :@computed_region_2dna_qi2s :@computed_region_k96s_3jcv  \
# 0                          26                         626
# 1                          26                         635
# 2                          26                         633
# 3                          52                         612
# 4                          69                         651
#
#   :@computed_region_kqwf_mjcx :@computed_region_qz3q_ghft  \
# 0                           7                       23667
# 1                           7                       23667
# 2                           6                       23679
# 3                          12                       23080
# 4                          12                       23080
#
#   :@computed_region_tatf_ua23 :@computed_region_ur2y_g4cx area_id area_name  \
# 0                        1086                         NaN      07  Wilshire
# 1                         332                         NaN      07  Wilshire
# 2                         809                         NaN      07  Wilshire
# 3                        1229                         NaN      07  Wilshire
# 4                        1105                         NaN      07  Wilshire
#
#   crm_cd crm_cd_1      ...        \
# 0    930      930      ...
# 1    626      626      ...
# 2    930      930      ...
# 3    626      626      ...
# 4    236      236      ...
#
#                                     premis_desc rpt_dist_no status  \
# 0                               PARK/PLAYGROUND        0724     AA
# 1  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)        0735     AA
# 2                                   PARKING LOT        0721     AA
# 3  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)        0759     AA
# 4  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)        0787     AO
#
#     status_desc time_occ vict_age vict_descent vict_sex  \
# 0  Adult Arrest     1050       41            B        M
# 1  Adult Arrest     0600       27            O        F
# 2  Adult Arrest     2350       20            H        F
# 3  Adult Arrest     2330       35            O        M
# 4   Adult Other     2000       43            K        F
#
#                                       weapon_desc weapon_used_cd
# 0                                   VERBAL THREAT            511
# 1  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)            400
# 2                                   VERBAL THREAT            511
# 3                     UNKNOWN WEAPON/OTHER WEAPON            500
# 4  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)            400
#
# [5 rows x 32 columns]

# %%
dir
# Out:
# <function dir>

# %%
# # Save json as json file
# with open('/Resources/data.txt', 'w') as f:
#   json.dump(results, f, ensure_ascii=False,indent=4, sort_keys=True)

# %%
# # open json file
# with open('../Resources/data.txt') as json_file:  
#     results = json.load(json_file)
# # Convert to pandas DataFrame
# la_crime_data = pd.DataFrame.from_records(results)

# %%
# Check data frame and columns for LA Crime Data
la_crime_data.head()
# Out:
#   :@computed_region_2dna_qi2s :@computed_region_k96s_3jcv  \
# 0                          26                         626
# 1                          26                         635
# 2                          26                         633
# 3                          52                         612
# 4                          69                         651
#
#   :@computed_region_kqwf_mjcx :@computed_region_qz3q_ghft  \
# 0                           7                       23667
# 1                           7                       23667
# 2                           6                       23679
# 3                          12                       23080
# 4                          12                       23080
#
#   :@computed_region_tatf_ua23 :@computed_region_ur2y_g4cx area_id area_name  \
# 0                        1086                         NaN      07  Wilshire
# 1                         332                         NaN      07  Wilshire
# 2                         809                         NaN      07  Wilshire
# 3                        1229                         NaN      07  Wilshire
# 4                        1105                         NaN      07  Wilshire
#
#   crm_cd crm_cd_1      ...        \
# 0    930      930      ...
# 1    626      626      ...
# 2    930      930      ...
# 3    626      626      ...
# 4    236      236      ...
#
#                                     premis_desc rpt_dist_no status  \
# 0                               PARK/PLAYGROUND        0724     AA
# 1  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)        0735     AA
# 2                                   PARKING LOT        0721     AA
# 3  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)        0759     AA
# 4  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)        0787     AO
#
#     status_desc time_occ vict_age vict_descent vict_sex  \
# 0  Adult Arrest     1050       41            B        M
# 1  Adult Arrest     0600       27            O        F
# 2  Adult Arrest     2350       20            H        F
# 3  Adult Arrest     2330       35            O        M
# 4   Adult Other     2000       43            K        F
#
#                                       weapon_desc weapon_used_cd
# 0                                   VERBAL THREAT            511
# 1  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)            400
# 2                                   VERBAL THREAT            511
# 3                     UNKNOWN WEAPON/OTHER WEAPON            500
# 4  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)            400
#
# [5 rows x 32 columns]

# %%
# Display Column Names
list(la_crime_data)
# Out:
# [':@computed_region_2dna_qi2s',
#  ':@computed_region_k96s_3jcv',
#  ':@computed_region_kqwf_mjcx',
#  ':@computed_region_qz3q_ghft',
#  ':@computed_region_tatf_ua23',
#  ':@computed_region_ur2y_g4cx',
#  'area_id',
#  'area_name',
#  'crm_cd',
#  'crm_cd_1',
#  'crm_cd_2',
#  'crm_cd_3',
#  'crm_cd_4',
#  'crm_cd_desc',
#  'cross_street',
#  'date_occ',
#  'date_rptd',
#  'dr_no',
#  'location',
#  'location_1',
#  'mocodes',
#  'premis_cd',
#  'premis_desc',
#  'rpt_dist_no',
#  'status',
#  'status_desc',
#  'time_occ',
#  'vict_age',
#  'vict_descent',
#  'vict_sex',
#  'weapon_desc',
#  'weapon_used_cd']

# %%
# Number of records 
len(la_crime_data)
# Out:
# 1931442

# %%
# Adding LocationFormatted to get Latitude and Longitude
#la_crime_data["LocationFormatted"] = la_crime_data["Location "].str.strip("()")

# %%
# Add Longitude and Latitude columns and populate 
la_crime_data["LNG"] = la_crime_data["location_1"][0]["coordinates"][0]
la_crime_data["LAT"] = la_crime_data["location_1"][0]["coordinates"][1]
la_crime_data.head()
# Out:
#   :@computed_region_2dna_qi2s :@computed_region_k96s_3jcv  \
# 0                          26                         626
# 1                          26                         635
# 2                          26                         633
# 3                          52                         612
# 4                          69                         651
#
#   :@computed_region_kqwf_mjcx :@computed_region_qz3q_ghft  \
# 0                           7                       23667
# 1                           7                       23667
# 2                           6                       23679
# 3                          12                       23080
# 4                          12                       23080
#
#   :@computed_region_tatf_ua23 :@computed_region_ur2y_g4cx area_id area_name  \
# 0                        1086                         NaN      07  Wilshire
# 1                         332                         NaN      07  Wilshire
# 2                         809                         NaN      07  Wilshire
# 3                        1229                         NaN      07  Wilshire
# 4                        1105                         NaN      07  Wilshire
#
#   crm_cd crm_cd_1   ...    status   status_desc time_occ vict_age  \
# 0    930      930   ...        AA  Adult Arrest     1050       41
# 1    626      626   ...        AA  Adult Arrest     0600       27
# 2    930      930   ...        AA  Adult Arrest     2350       20
# 3    626      626   ...        AA  Adult Arrest     2330       35
# 4    236      236   ...        AO   Adult Other     2000       43
#
#   vict_descent vict_sex                                     weapon_desc  \
# 0            B        M                                   VERBAL THREAT
# 1            O        F  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 2            H        F                                   VERBAL THREAT
# 3            O        M                     UNKNOWN WEAPON/OTHER WEAPON
# 4            K        F  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
#
#   weapon_used_cd       LNG      LAT
# 0            511 -118.3555  34.0761
# 1            400 -118.3555  34.0761
# 2            511 -118.3555  34.0761
# 3            500 -118.3555  34.0761
# 4            400 -118.3555  34.0761
#
# [5 rows x 34 columns]

# %%
# Add Zipcode column and populate
# search = SearchEngine(simple_zipcode=True)
# la_crime_data["zipcode"] = search.by_coordinates(la_crime_data["LAT"], la_crime_data["LNG"], radius=1, returns=1)[0].zipcode
#print(f"{result[0].zipcode},{result[0]}")

# %%
# #Create Latitude and Longtitude columns
# #la_crime_data.drop("LAT", axis=1, inplace=True)
# #la_crime_data.drop("LNG", axis=1, inplace=True)
# la_crime_data["LAT"] = la_crime_data["LocationFormatted"].str.split(",", n = 1, expand =True)[0]
# la_crime_data["LNG"] = la_crime_data["LocationFormatted"].str.split(",", n = 1, expand =True)[1]

# la_crime_data["LAT"] = pd.to_numeric(la_crime_data["LAT"],errors='coerce')
# la_crime_data["LNG"] = pd.to_numeric(la_crime_data["LNG"],errors='coerce')
# la_crime_data.head()

# %%
# #Read Zip code, latitude , longitude
# zip_data = pd.read_csv("../Resources/zipcode-data.csv")

# %%
# # Check data frame and columns for Zip data
# zip_data.head()

# %%
# # Remove all zipcode other than california
# zip_data =zip_data[zip_data.ZIP >= 90000]
# zip_data.head()

# %%
# # merging data - not working
# la_crime_data_merge = pd.merge(la_crime_data, zip_data,  how='left', on=["LAT","LNG"],validate="many_to_many")
# list(la_crime_data_merge)

# %%
# la_crime_data_merge.head()
# # la_crime_data_merge["LAT"].max()  #34.7907
# la_crime_data_merge["LNG"].max()  #0
# # la_crime_data_merge["LNG"].min()  # -118.8279

# %%
#Finding the area in Los Angeles with highest Crime rate.
la_crime_data["area_name"].groupby(la_crime_data["area_name"]).count().sort_values(ascending=False).plot(kind="barh")
plt.show()

# %%
# from pygeocoder import Geocoder
# results = Geocoder.reverse_geocode(33.974027,-118.249509)
# print(results[0])

# %%
# from uszipcode import SearchEngine
# #search = SearchEngine(simple_zipcode=True)
# result = search.by_coordinates(34.1577, -118.3727, radius=1, returns=1)
# print(f"{result[0].zipcode},{result[0]}")
