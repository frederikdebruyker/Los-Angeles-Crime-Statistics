# %%
# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata
import numpy as np


# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
#client = Socrata("data.lacity.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.lacity.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
#results = client.get("7fvc-faax", limit=2000000)

# Convert to pandas DataFrame
#results_df = pd.DataFrame.from_records(results)

# %%
types_df = pd.read_csv("Resources/los_angeles_crime_statistics.csv")
#types_df.info()
types_df.tail()
# Out:
#          Unnamed: 0  area_id area_name  crm_cd  crm_cd_4  \
# 1930531     1931437     21.0   Topanga     626       NaN
# 1930532     1931438     21.0   Topanga     420       NaN
# 1930533     1931439     21.0   Topanga     624       NaN
# 1930534     1931440     21.0   Topanga     310       NaN
# 1930535     1931441     21.0   Topanga     900       NaN
#
#                                              crm_cd_desc  \
# 1930531                INTIMATE PARTNER - SIMPLE ASSAULT
# 1930532  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 1930533                         BATTERY - SIMPLE ASSAULT
# 1930534                                         BURGLARY
# 1930535                         VIOLATION OF COURT ORDER
#
#                         date_occ                date_rptd      dr_no  \
# 1930531  2019-02-23T00:00:00.000  2019-02-23T00:00:00.000  192106365
# 1930532  2019-02-22T00:00:00.000  2019-02-23T00:00:00.000  192106374
# ...

# %%
zipcodes_df = types_df['zipcode'].unique()
zipcodes_df
# Out:
# array([90036, 90048, 90005, 90019, 90016, 90038, 90018, 90069, 90211,
#        90014, 90035, 90710, 91331, 90044, 91402, 90062, 91411, 90077,
#        91405, 91356, 91335, 91316, 91436, 90002, 90006, 90024, 91423,
#        91406, 90003, 90045, 91607, 91343, 91303, 90017, 90012, 90015,
#        90071, 90057, 90029, 90037, 90007, 90744, 90501, 90064, 90212,
#        91401, 90065, 90026, 90011, 90001, 90033, 90291, 90066, 90292,
#        91605, 91352, 91325, 91304, 90010, 90013, 90008, 90079, 90021,
#        90031, 90032, 90732, 90731, 90248, 90004, 90028, 90025, 90272,
#        90404, 91403, 90041, 90039, 90042, 90027, 90047, 90305, 90043,
#        90230, 90405, 90304, 90301, 91604, 91608, 91601, 91606, 91342,
#        91214, 91040, 91326, 91324, 91306, 91344, 90247, 90061, 90059,
#        91340, 91345, 91367, 90063, 90023, 90717, 90822, 90046, 90020,
#        90067, 90210, 90034, 90049, 90402, 91201, 90302, 90056, 90094,
# ...

# %%
print(len(zipcodes_df))
# Out:
# 234

# %%
zip_counts = types_df["zipcode"].value_counts()
zip_counts
# Out:
# 90037    57434
# 90003    52027
# 90028    51985
# 90011    44326
# 90057    43121
# 90062    41388
# 90029    38193
# 90014    34519
# 91303    34475
# 90018    34427
# 91402    34363
# 91405    31831
# 90044    30288
# 90007    29155
# 91324    29101
# 91335    28639
# 91331    28392
# 91605    28270
# 91343    27813
# 90002    27737
# 91606    26852
# 91306    25179
# 90008    25092
# 90744    24445
# 90033    24443
# 90731    23660
# 90036    23500
# 90010    22838
# 90016    21687
# 90019    21416
#          ...
# 91101        1
# 90605        1
# 93534        1
# 91207        1
# 91001        1
# 90505        1
# 91016        1
# 93591        1
# 91011        1
# 90604        1
# 92372        1
# 91723        1
# 91732        1
# 91740        1
# 90250        1
# 90265        1
# 91741        1
# 90701        1
# 90713        1
# 90715        1
# 91765        1
# 91789        1
# 90740        1
# 90746        1
# 91768        1
# 91775        1
# 90806        1
# ...
