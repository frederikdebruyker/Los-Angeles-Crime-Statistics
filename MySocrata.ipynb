# %%
#y1CHHu67Xs07VAvgf79tV1KwA

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.lacity.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.lacity.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("7fvc-faax", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   :@computed_region_2dna_qi2s :@computed_region_k96s_3jcv  \
# 0                          76                         703
# 1                          76                         542
# 2                          76                         542
# 3                          26                         626
# 4                          26                         635
#
#   :@computed_region_kqwf_mjcx :@computed_region_qz3q_ghft  \
# 0                           9                       23075
# 1                           9                       23074
# 2                           9                       23074
# 3                           7                       23667
# 4                           7                       23667
#
#   :@computed_region_tatf_ua23 :@computed_region_ur2y_g4cx area_id area_name  \
# 0                        1319                         NaN      01   Central
# ...

# %%
import os
# Note: we don't need Pandas
# Filters allow you to accomplish many basic operations automatically

from sodapy import Socrata

import pandas as pd
import time
# ## Find Some Data
#
# As in the first example, I'm using the Santa Fe political contribution dataset.
#
# `https://opendata.socrata.com/dataset/Santa-Fe-Contributors/f92i-ik66.json`

# In[2]:


socrata_domain = 'data.lacity.org' #'opendata.socrata.com'
socrata_dataset_identifier = '7fvc-faax'

# If you choose to use a token, run the following command on the terminal (or add it to your .bashrc)
# $ export SODAPY_APPTOKEN=<token>
#socrata_token = os.environ.get("SODAPY_APPTOKEN")

client = Socrata(socrata_domain, 'y1CHHu67Xs07VAvgf79tV1KwA')
results = client.get(socrata_dataset_identifier,limit=5000,offset=1,order="'Date Occurred','Time Occured' DESC")
df = pd.DataFrame.from_dict(results)
len(df)
# In[3]:
client = Socrata(socrata_domain, 'y1CHHu67Xs07VAvgf79tV1KwA')
for i in range(0,10):
    offset_value = i*5000
    results = client.get(socrata_dataset_identifier,limit=5000,offset=offset_value,order="'Date Occurred','Time Occured' DESC")
#    results = client.get(socrata_dataset_identifier,where="'Date Occurred' >=03/01/2019 and 'Date Occurred' <= 03/31/2019","order="'Date Occurred','Time Occured' DESC")
    print(f" {i}")
    df = pd.DataFrame.from_records(results)
    print(f"{max_key}")
#     df.append(results)
#     time.sleep(10)
#     if i == 1:
#     df = pd.DataFrame.from_dict(results)
#         print("I am making")
#         print(f" {len(results)}")
#     else:
#         df.append(results)
#         print("I am appending")
#         print(f" {len(results)}")
len(df)

# ## Use Metadata to Plan Your Query
# You've probably looked through the column names and descriptions in the web UI,
# but it can be nice to have them right in your workspace as well.

# In[4]:


# metadata = client.get_metadata(socrata_dataset_identifier)
# [x['name'] for x in metadata['columns']]
# Out:
#  0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-269309571582> in <module>()
#      35     print(f" {i}")
#      36     df = pd.DataFrame.from_records(results)
# ---> 37     max_key = max(results[1].values())
#      38     print(f"{max_key}")
#      39 #     df.append(results)
#
# TypeError: '>' not supported between instances of 'dict' and 'str'

# %%
metadata
# Out:
# {'id': '7fvc-faax',
#  'name': 'Crime Data from 2010 to Present',
#  'attribution': 'Los Angeles Police Department',
#  'attributionLink': 'http://data.lacity.org',
#  'averageRating': 0,
#  'category': 'A Safe City',
#  'createdAt': 1492022738,
#  'description': 'This dataset reflects incidents of crime in the City of Los Angeles dating back to 2010. This data is transcribed from original crime reports that are typed on paper and therefore there may be some inaccuracies within the data. Some location fields with missing data are noted as (0°, 0°). Address fields are only provided to the nearest hundred block in order to maintain privacy. This data is as accurate as the data in the database. Please note questions or concerns in the comments.',
#  'displayType': 'table',
#  'downloadCount': 310,
#  'hideFromCatalog': False,
#  'hideFromDataJson': False,
#  'indexUpdatedAt': 1500695976,
#  'licenseId': 'CC0_10',
#  'newBackend': True,
#  'numberOfComments': 0,
#  'oid': 26430738,
# ...
